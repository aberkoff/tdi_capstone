# %%
import seaborn as sns
sns.set()
import requests
import pandas as pd

# %%
def checkouts(month, year):
    params = { 'UsageClass'        :'Digital', 
               'MaterialType': 'AUDIOBOOK',
              'CheckoutMonth': month,
              'CheckoutYear': year
             }
    headers = { 'user-agent'   : 'TDI' }   #  Need to supply a user agent other than the default provided 
                                           #  by requests for the API to accept the query.
    return requests.get('https://data.seattle.gov/resource/tmmm-ytt6.json', 
                        params=params, headers=headers)

# %%
info = checkouts(1, 2022)

# %%
df=pd.read_json(info.text)

# %%
df[990:]
# Out:
#     usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 990    Digital    OverDrive    AUDIOBOOK          2022              1
# 991    Digital    OverDrive    AUDIOBOOK          2022              1
# 992    Digital    OverDrive    AUDIOBOOK          2022              1
# 993    Digital    OverDrive    AUDIOBOOK          2022              1
# 994    Digital    OverDrive    AUDIOBOOK          2022              1
# 995    Digital    OverDrive    AUDIOBOOK          2022              1
# 996    Digital    OverDrive    AUDIOBOOK          2022              1
# 997    Digital    OverDrive    AUDIOBOOK          2022              1
# 998    Digital    OverDrive    AUDIOBOOK          2022              1
# 999    Digital    OverDrive    AUDIOBOOK          2022              1
#
#      checkouts                                              title  \
# 990          1  Amy Wu and the Perfect Bao: Amy Wu Series, Boo...
# ...
